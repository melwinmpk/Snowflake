# %% [markdown]
# <p>Which is the most accurate description of the Snowflake Partner Connect? Choose one correct value.</p>
# <ul>
# <li><b>The Snowflake Partner Connect allows you to easily create trial account with selected Snowflake business partners and integrate these accounts with Snowflake.</b></li>
# <li>The Snowflake Partner Connect allows Snowflake data to be exported to a business partners Snowflake account.</li>
# <li>The Snowflake Partner Connect exposes contact details for third-party data providers, so a user can connect with them in their own time.</li>
# <li>The Snowflake Partner Connect allows an account to securely import data from a business partners Snowflake account.</li>
# </ul>
#
#
# <p>Time Travel is not possible on transient tables. True or false?</p>
# <ul>
# <li>True</li>
# <li><b>False</b></li>
# </ul>
#
# <p>The ACCOUNTADMIN can perform the same functions as the SECURITYADMIN, SYSADMIN & ORGAMIN. True or false?</p>
# <ul>
# <li>True</li>
# <li><b>False</b></li>
# </ul>
#
# <p>Which semi-structured data formats do Snowflake natively store and query? Select all that apply.</p>
# <ul>
# <li><b>AVRO</b></li>
# <li><b>PARQUET</b></li>
# <li>PDF</li>
# <li>CSV</li>
# <li>RCFile</li>
# <li><b>ORC</b></li>
# <li><b>JSON</b></li>
# <li><b>XML</b></li>
# <li>SequenceFile</li>
# </ul>
#
# <p>What is the behavior of the COPY INTO <table> command when the ON_ERROR option is set to CONTINUE? Choose one correct value.</p>
# <ul>
# <li>Abort load operation.</li>
# <li>Skip file when error is found</li>
# <li>Skip a file when a certain number of errors is found.</li>
# <li><b>Load the file if errors are found</b></li>
# </ul>
#
# <p>Which layers are in Snowflake’s Multi-cluster Shared Data Architecture? Choose two correct values.</p>
# <ul>
# <li><b>Compute / Query Processing Layer</b></li>
# <li>Metadata Layer</li>
# <li>ETL Layer</li>
# <li><b>Storage Layer</b></li>
# <li>Unloading Layer</li>
# </ul>
#
# <p>Data providers can share data with a data consumer in a different cloud region or cloud provider. True or false?</p>
# <ul>
# <li>True</li>
# <li><b>False</b></li>
# </ul>
#
# <p>When copying files from a table to an internal stage using the COPY INTO <location> command, the results are split into multiple files. Which copy option would I use to ensure only one file is produced? Choose one correct value.</p>
# <ul>
# <li>INCLUDE_QUERY_ID</li>
# <li>OVERWRITE</li>
# <li>MAX_FILE_SIZE</li>
# <li><b>SINGLE</b></li>
# </ul>
#
# <p>How many databases objects can a data provider add to a SHARE object? Choose one correct value.</p>
# <ul>
# <li>5</li>
# <li>2</li>
# <li><b>1</b></li>
# <li>Unlimited</li>
# </ul>
#
# <p>Which types of notation are used to traverse semi-structured data natively in Snowflake? Select all that apply.</p>
# <ul>
# <li>Colon notation</li>
# <li>Bracket notation</li>
# <li>Dollar notation</li>
# <li><b>Dot notation</b></li>
# </ul>

# %% [markdown]
# <p>Databases are not required to have a unique identifier. True or false?</p>
# <ul>
# <li>True</li>
# <li><b>False</b></li>
# </ul>
#
# <p>What is the purpose of the VALIDATE function? Choose one correct value.</p>
# <ul>
# <li>Outputs a pdf to a configured stage of all the errors of a past execution.</li>
# <li>Allows a user to perform a dry-run of the load process to expose errors.</li>
# <li>Allows a user to view all errors encountered during all previous runs of a COPY INTO execution.</li>
# <li><b>Allows a user to view all errors encountered during a previous COPY INTO execution.</b></li>
# </ul>
#
# <p>The following query can make use of the results cache: SELECT NAME, EMP_ID, CURRENT_TIME() FROM EMPLOYEE. True of false?</p>
# <ul>
# <li><b>False</b></li>
# <li>True</li>
# </ul>
#
# <p>What is the recommended compressed file size when loading data into Snowflake? Choose one correct value.</p>
# <ul>
# <li>50-100mb</li>
# <li>10-50mb</li>
# <li><b>100-250mb</b></li>
# <li>100-200mb</li>
# </ul>
#
# <p>Which languages can be used to develop a User Defined Function (UDF)? Choose four correct values.</p>
# <ul>
# <li>C++</li>
# <li>C#</li>
# <li>GO</li>
# <li><b>SQL</b></li>
# <li><b>Java</b></li>
# <li><b>Python</b></li>
# <li><b>JavaScript</b></li>
# </ul>
#
# <p>Which SQL commands would show the contents of a stage? Select all that apply.</p>
# <ul>
# <li>SHOW STAGE MY_STAGE;</li>
# <li><b>LIST @MY_STAGE;</b></li>
# <li>SHOW STAGE @MY_STAGE;</li>
# <li><b>ls @MY_STAGE;</b></li>
# </ul>
#
# <p>Every securable object is owned by a single role. True or false?</p>
# <ul>
# <li><b>True</b></li>
# <li>False</li>
# </ul>
#
# <p>Which system-defined role is it recommended to assign custom roles to? Choose one correct value.</p>
# <ul>
# <li>ACCOUNTADMIN</li>
# <li>ORGADMIN</li>
# <li>USERADMIN</li>
# <li>SECURITYADMIN</li>
# <li><b>SYSADMIN</b></li>
# </ul>
#
# <p>In which state is a Virtual Warehouse billable? Choose one correct value.</p>
# <ul>
# <li><b>STARTED</b></li>
# <li>SUSPENDED</li>
# <li>INITIATED</li>
# <li>RESUME</li>
# </ul>
#
# <p>What is the default value for the table property DATA_RETENTION_TIME_IN_DAYS for an account on the enterprise edition of Snowflake? Choose one correct value.</p>
# <ul>
# <li>90</li>
# <li><b>1</b></li>
# <li>10</li>
# <li>0</li>
# </ul>

# %% [markdown]
# <p>What are the two scaling policies that can be defined when creating a multi-cluster warehouse? Choose two correct values.</p>
# <ul>
# <li><b>Standard</b></li>
# <li>Maximized</li>
# <li>Minimum</li>
# <li>Conservative</li>
# <li><b>Economy</b></li>
# </ul>

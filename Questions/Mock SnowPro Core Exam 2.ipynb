# %% [markdown]
# <p>When processing semi-structured data into structured (i.e., a table), what is the correct way to cast a column into a data type?
# Assume the target column name is CustomerName, and the data type is String.</p>
# <ul>
# <li><b>SELECT col1:CustomerName::String</b></li>
# <li>SELECT col1 AS CustomerName WITH DATATYPE AS String</li>
# <li>SELECT CAST(col1:CustomerName AS String)</li>
# </ul>
#
# <p>Which of the following is true when a virtual warehouse is scaled up to a larger size? Select all that apply.</p>
# <ul>
# <li><b>Only new queries benefit from the larger cluster size.</b></li>
# <li>The virtual warehouse cannot be scaled down to a smaller size.</li>
# <li>All existing queries are terminated and must be re-submitted.</li>
# <li><b>The charging for the new size is not started until all new nodes in the larger virtual warehouse are provisioned.</b></li>
# <li><b>The increased size does not affect any queries already executing on the virtual warehouse</b></li>
# </ul>
#
# <p>What is the minimum Snowflake edition that supports fail-safe?</p>
# <ul>
# <li>Business Critical</li>
# <li>Virtual Private Snowflake</li>
# <li><b>Standard</b></li>
# <li>Enterprise</li>
# </ul>
#
# <p>True or False: When setting up replication for cross-cloud or cross-region data sharing, the data provider must replicate data once for each data consumer.</p>
# <ul>
# <li><b>False</b></li>
# <li>True</li>
# </ul>
#
# <p>Which of the following statements are true regarding Snowpark?</p>
# <ul>
# <li><b>
# When using Snowpark, Snowflake operations are performed lazily.</b></li>
# <li>When using Snowpark, Snowflake operations are performed immediately on the client side.</li>
# <li>Snowpark uses the Hadoop query engine for execution.</li>
# <li><b>Functions defined in Snowpark can be pushed down to the server (Snowflake) for execution.</b></li>
# </ul>
#
# <p>Query Result Cache reuse can be turned off using which parameter?</p>
# <ul>
# <li>ENABLE_QUERY_RESULT_CACHE</li>
# <li><b>USE_CACHED_RESULT</b></li>
# <li>PURGE_CACHED_RESULTS</li>
# <li>DISABLE_QUERY_RESULT_CACHE</li>
# </ul>
#
#
# <p>In a VARIANT column, the NULL values are stored as a literal string "null"</p>
# <ul>
# <li>False</li>
# <li><b>True</b></li>
# </ul>
#
# <p>Which of the following is true regarding privileges and roles in Snowflake? Select all that apply</p>
# <ul>
# <li>New custom roles cannot be created.</li>
# <li><b>Privileges can be assigned to roles.</b></li>
# <li>Privileges can be assigned to users directly</li>
# <li><b>Roles can be assigned to users.</b></li>
# </ul>
#
# <p>Which of the following are Snowflake Business Intelligence partners? Select all that apply.</p>
# <ul>
# <li><b>PowerBI</b></li>
# <li><b>Oracle</b></li>
# <li><b>MicroStrategy</b></li>
# <li><b>Looker</b></li>
# <li><b>Tableau</b></li>
# </ul>
#
# <p>From a cardinality (number of distinct values) perspective, which columns should you consider adding to a clustering key?</p>
# <ul>
# <li>Only columns that have a low cardinality.</li>
# <li>
# Only columns that have a high cardinality.</li>
# <li><b>Columns that have large enough distinct values to enable efficient partition pruning.</b></li>
# <li>Columns that have small enough distinct values to enable efficient grouping in micro-partition.</li>
# <li>The cardinality of columns doesn't matter when defining a clustering key.</li>
# </ul>
#
# <p>External Tokenization provides what sort of security in Snowflake?</p>
# <ul>
# <li>Row-level security</li>
# <li>Object Security</li>
# <li>Database-level security</li>
# <li><b>Column-level security</b></li>
# </ul>
#
# <p>Snowpipe can reload a file with the same name if it has been modified.</p>
# <ul>
# <li><b>Flase</b></li>
# <li>True</li>
# </ul>
#
# <p>Snowflake allows which of the following access control methods? Select all that apply.</p>
# <ul>
# <li>Management access control (MAC)</li>
# <li>Global access control (GAC)</li>
# <li><b>Role-based access control (RBAC)</b></li>
# <li><b>Discretionary access control (DAC)</b></li>
# </ul>
#
# <p>Which of the following is true regarding Query Result Cache for a given query? Select all that apply.</p>
# <ul>
# <li><b>
# If a query reuses the query result cache, it is extended by another 24 hours</b></li>
# <li><b>
# If no new query reuses the query result cache, the cache is purged after 24 hours.</b></li>
# <li><b>The query result cache may be extended for up to a maximum of 31 days</b></li>
# <li>The query result cache can be manually purged</li>
# </ul>
#
# <p>Which of the following objects can be cloned? Select all that apply.</p>
# <ul>
# <li><b>Sequence</b></li>
# <li>Virtual Warehouse</li>
# <li><b>
# File Format</b></li>
# <li>Share</li>
# <li><b>Stage</b></li>
# <li>Task</li>
# </ul>
#
# <p>What is the number of nodes in a Medium virtual warehouse?</p>
# <ul>
# <li>6</li>
# <li>256</li>
# <li><b>4</b></li>
# <li>3</li>
# </ul>
#
# <p>What type of metadata is maintained for each micro-partition? Select all that apply.</p>
# <ul>
# <li><b>Count of distinct values for each column</b></li>
# <li><b>Maximum & minimum of each column</b></li>
# <li>Mean, median & mode of each column</li>
# <li><b>Range of column values</b></li>
# </ul>
#
# <p>An administrator must grant explicit privileges on a cloned database as the cloning does not copy the privileges of the source database.</p>
# <ul>
# <li><b>True</b></li>
# <li>False</li>
# </ul>
#
# <p>Which of the following are examples of virtual warehouse sizes?</p>
# <ul>
# <li><b>Medium</b></li>
# <li>Low</li>
# <li><b>6X-Large</b></li>
# <li><b>X-Small</b></li>
# <li>High</li>
# </ul>
#
# <p>When a database or a schema is cloned, which of the following statements are regarding Snowpipes in that database?</p>
# <ul>
# <li><b>Any Snowpipes that reference an external stage are cloned</b></li>
# <li>Any Snowpipes that reference an external stage are NOT cloned</li>
# <li>Any Snowpipes that reference an internal stage are cloned</li>
# <li><b>Any Snowpipes that reference an internal stage are NOT cloned</b></li>
# </ul>
#
#
# <p>Which of the following is true regarding Query Profile? Select all that apply.</p>
# <ul>
# <li>A query profile is not available for queries that have not been completed.</li>
# <li><b>It shows a graphical representation of all steps.</b></li>
# <li><b>A query profile is available for all queries, whether running, completed, or failed.</b></li>
# <li><b>It shows the query plan for a query.</b></li>
# </ul>
#
# <p>When cloning a database, your current role must have which privilege (as a minimum) on the source database?</p>
# <ul>
# <li>WRITE</li>
# <li>SELECT</li>
# <li><b>USAGE</b></li>
# </ul>
#
# <p>Which of the following statements is true regarding the USERADMIN role? Select all that apply.</p>
# <ul>
# <li><b>A user with the USERADMIN role can create new users.</b></li>
# <li><b>A user with the USERADMIN role can create new roles.</b></li>
# <li>A user with the USERADMIN role can manage the whole account.</li>
# <li>A user with the USERADMIN role can manage object grants.</li>
# </ul>
#
# <p>Which of the following accurately describes the highlighted statistics? Select all that apply.</p>
# <img src='https://github.com/melwinmpk/Snowflake/assets/25386607/11825fd1-5466-43f0-82d1-6559bec8aa20'></img>
# <ul>
# <li>The query profile indicates that the metadata cache was used.</li>
# <li><b>The query profile indicates ineffective partition pruning.</b></li>
# <li><b>The query profile indicates that the query is too large to fit in the virtual warehouse memory.</b></li>
# <li>The query profile indicates that the query result cache was used.</li>
# </ul>
#
# <p>For data loading and transformation, the approach recommended by Snowflake is?</p>
# <ul>
# <li><b>ELT (Extract, Load, Transform)</b></li>
# <li>ETL (Extract, Transform, Load)</li>
# </ul>
#
# <p>Snowflake allows which two of the following approaches for loading data?</p>
# <ul>
# <li>
# Intermittent Data Loading</li>
# <li><b>Continuous Data Loading</b></li>
# <li><b>Bulk Data Loading</b></li>
# </ul>
#
# <p>Which statements best describe scaling up a virtual warehouse in Snowflake? Select all that apply.</p>
# <ul>
# <li><b>Generally, scaling up is performed to accommodate more complex workloads.</b></li>
# <li>Scaling up means decreasing the size of a virtual warehouse due to improved query processing efficiency.</li>
# <li><b>When scaling up, the size of the virtual warehouse is increased to a larger size.</b></li>
# <li><b>
# Additional nodes are added to a virtual warehouse when scaling up.</b></li>
# </ul>
#
# <p>Which of the following are data-sharing services provided by Snowflake?</p>
# <ul>
# <li><b>Snowflake Marketplace</b></li>
# <li><b>Data Exchange</b></li>
# <li><b>Direct Sharing</b></li>
# <li>Seamless Data Share</li>
# </ul>
#
# <p>Which of the following statements about a multi-cluster virtual warehouse in auto-scale mode is true?</p>
# <ul>
# <li><b>
# When Snowflake detects that queries are beginning to queue, additional warehouses are started.</b></li>
# <li><b>When the query demand decreases, warehouses are progressively shut down</b></li>
# <li><b>
# Multi-cluster virtual warehouses support the same properties and actions as regular virtual warehouses. They can be suspended, resumed, and modified to a different size.</b></li>
# <li>
# Multi-cluster virtual warehouses do not support Suspend, Resume, or Resize operations</li>
# </ul>
#
# <p>Is it possible to share data with a Snowflake customer whose Snowflake instance exists in a different region than the data provider?</p>
# <ul>
# <li>
# Yes. Nothing special needs to be done to enable cross-region data sharing.</li>
# <li><b>Yes, but you must enable replication first to enable cross-region data sharing.</b></li>
# <li>No, it is not possible to share with customers in other regions.</li>
# </ul>
#
# <p>A Table UDF can return what type of results? Select all that apply</p>
# <ul>
# <li><b>For each input, it can return one-row containing multiple columns</b></li>
# <li><b>For each input, it can return one row containing a single column</b></li>
# <li><b>For each input, it can return zero rows</b></li>
# <li><b>For each input, it can return multiple rows containing a single columns</b></li>
# <li><b>For each input, it can return multiple rows containing multiple columns</b></li>
# </ul>
#
# <p>Which of the following statements best describe Snowflake's multi-factor authentication (MFA) capability? Select all that apply</p>
# <ul>
# <li><b>SnowSQL, Snowflake ODBC, JDBC, and the Python Connector are all MFA-compatible.</b></li>
# <li><b>Multi-factor authentication (MFA) is enabled by default for all users; however, users must enroll themselves in MFA manually</b></li>
# <li>Only Snowflake's Web Interface and SnowSQL allow multi-factor authentication</li>
# <li><b>An administrator can turn off a user's MFA</b></li>
# </ul>
#
#
# <p>Which of the following objects can be shared? Select all that apply.</p>
# <ul>
# <li><b>Secure UDFs</b></li>
# <li>Views</li>
# <li>Materalized Views</li>
#     <li><b>Secure Views</b></li>
# <li><b>Tables</b></li>
# <li><b>Secure Materalized Views</b></li>
# </ul>
#
# <p>What is the minimum Snowflake edition that supports private connectivity to Snowflake?</p>
# <ul>
# <li><b>Another Snowflake customer</b></li>
# <li><b>Multiple Snowflake customers</b></li>
# <li><b>A non-Snowflake customer</b></li>
# <li>Google Drive users</li>
# <li>One Drive Users</li>
# </ul>
#
# <p>What is the minimum Snowflake edition that supports private connectivity to Snowflake?</p>
# <ul>
# <li>Standard</li>
# <li>Enterprise</li>
# <li>Virtual Private Snowflake</li>
# <li><b>Business Critical</b></li>
# </ul>
#
# <p>As an administrator, you are required to find and list all tables with a size greater than 1 TB. You must also include tables created and deleted in the last month. Which one of the following options should you use?</p>
# <ul>
# <li>Use the table functions provided in the INFORMATION_SCHEMA schema</li>
# <li>Use Snowsight to show this information</li>
# <li><b>Query the views in the ACCOUNT_USAGE schema</b></li>
# <li>Go through the logs for COPY command to identify which tables were loaded with large volumes of data</li>
# </ul>
#
# <b>ACCOUNT_USAGE views include information for all dropped objects. Many of these views include a DELETED column showing the dropped object's information. INFORMATION_SCHEMA does not include dropped objects. https://docs.snowflake.com/en/sql-reference/account-usage#differences-between-account-usage-and-information-schema</b>
#
#
# <p>In the Snowsight worksheet view, which of the following can be selected to set the context under which a query executes?</p>
# <ul>
# <li><b>Schema</b></li>
# <li><b>Database</b></li>
# <li>Table</li>
# <li>User</li>
# <li><b>Role</b></li>
# <li><b>Virtual Warehouse</b></li>
# </ul>
#
# <p>True or False: Snowflake recommends a maximum of 3 or 4 columns in a clustering key.</p>
# <ul>
# <li>False</li>
# <li><b>True</b></li>
# </ul>
#
# <p>Which of the following sentences accurately describes scaling out in Snowflake? Choose all that apply.</p>
# <ul>
# <li>Scaling out is accomplished by increasing or decreasing the size of a virtual warehouse.</li>
# <li><b>Scaling out is accomplished through the usage of multi-cluster virtual warehouses.</b></li>
# <li><b>Scaling out can assist in reducing query queuing.</b></li>
# </ul>
#
# <p>Snowpipe can load data directly from which of the following? Select all that apply.</p>
# <ul>
# <li><b>Internal Stage</b></li>
# <li>Snowflake tables</li>
# <li>On-premises system</li>
# <li><b>External Stage</b></li>
# </ul>
#
#
# <p>The cloud services layer in Snowflake provides which of the following functions? Select all that apply.</p>
# <ul>
# <li><b>Cloning</b></li>
# <li>Storage for data</li>
# <li><b>Data Sharing</b></li>
# <li><b>Transaction control / ACID compliance</b></li>
# </ul>
#
#
#
# <p>A virtual warehouse was started, used for 5 minutes and 15 seconds, and shut down afterward. The customer will be charged for how many seconds?</p>
# <ul>
# <li>0 seconds</li>
# <li>360 seconds</li>
# <li>3600 seconds</li>
# <li><b>315 seconds</b></li>
# </ul>
#
#
#
# <p>True or False: A cloned object does not contribute to overall storage until DML operations on the source or target object are done.</p>
# <ul>
# <li><b>True</b></li>
# <li>False</li>
# </ul>
#
#
# <p>During a weekly release cycle, which of the following accounts may be updated on the first day of release?</p>
# <ul>
# <li>All business critical edition accounts</li>
# <li><b>Only those Enterprise edition accounts which have opted into early access</b></li>
# <li><b>Standard edition accounts</b></li>
# <li>All Enterprise edition accounts</li>
# </ul>
#
#
# <p>Which of the following are Time Travel SQL extensions?</p>
# <ul>
# <li>TIME</li>
# <li><b>UNDROP</b></li>
# <li><b>AT</b></li>
# <li><b>BEFORE</b></li>
# <li>TIMETRAVEL</li>
# </ul>
#
#
# <p>Snowflake supports which of the following authentication mechanisms? Select all that apply</p>
# <ul>
# <li><b>Multi-factor authentication</b></li>
# <li><b>Key Pair Authentication</b></li>
# <li>MD5 authentication</li>
# <li>Plain Text Password authentication</li>
# </ul>
#
#
# <p>Which simple transformations can be used while loading data through the COPY command?</p>
# <ul>
# <li>Transpose</li>
# <li>Pivot</li>
# <li><b>Truncate</b></li>
# <li><b>Cast</b></li>
# <li><b>Omit columns</b></li>
# <li><b>Reorder Columns</b></li>
# </ul>
#
#
# <p></p>
# <img src='https://github.com/melwinmpk/Snowflake/assets/25386607/e3c89682-99cf-4607-b8c7-039700c52275'></img>
# <ul>
# <li>
# The query profile indicates ineffective partition pruning.</li>
# <li><b>The query profile indicates effective partition pruning</b></li>
# <li><b>The query profile indicates that the virtual warehouse cache was used.</b></li>
# <li>The query profile indicates that the virtual warehouse used is too small for the query.</li>
# </ul>
#
#
# <p>Which of the following is true regarding Time Travel in Snowflake? Select all that apply.</p>
# <ul>
# <li><b>Undrop allows users to restore dropped tables, schemas, and databases.</b></li>
# <li><b>Tables, Schemas, and Databases are not immediately deleted physically but instead marked as deleted.</b></li>
# <li>Undrop can be used to reset a Snowflake account.</li>
# <li>Undrop can be used to recover data in external stages.</li>
# </ul>
#
#
# <p>What is meant by scaling down a virtual warehouse in Snowflake? Select all that apply.</p>
# <ul>
# <li><b>Scaling down means resizing the virtual warehouse to a smaller size.</b></li>
# <li><b>Typically a virtual warehouse is scaled down as a response to decreased query complexity.</b></li>
# <li><b>Nodes are de-provisioned when a virtual warehouse is scaled down.</b></li>
# <li>Scaling down means increasing the size of a virtual warehouse to accommodate more complex workloads</li>
# </ul>
#
#
# <p>The query history in the Snowflake Web Interface is kept for how many days?</p>
# <ul>
# <li>30 days</li>
# <li>6 months</li>
# <li>365 days</li>
# <li><b>14 days</b></li>
# </ul>

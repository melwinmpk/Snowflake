# %% [markdown]
# <p>Which of the following contributes towards the storage costs in Snowflake?</p>
# <ul>
#     <li>Warehouse Cache</li>
#     <li><b>Transient Tables</b></li>
#     <li>Query Result Cache</li>
#     <li><b>Permanent Tables</b></li>
#     <li><b>Temporary Tables</b></li>
# </ul>
#
# <p>
# Caching is NOT considered for determining storage costs. The query result cache & metadata cache are part of the cloud services layer.<br>
# The warehouse cache (local disk cache) is part of a virtual warehouse and does NOT contribute to storage costs.
# </p>  <br>  <br>
#
# <p>Which statements are correct regarding the costs of using event notifications to refresh a directory table's metadata?</p>
# <ul>
#     <li><b>A small maintenance cost is charged for the refresh operation.</b></li>
#     <li>The event notifications are free.</li>
#     <li><b>An additional cost is charged for the event notifications</b></li>
#     <li>The refresh operation is free.</li>
# </ul>
#
# <p>What privilege is required to resize a virtual warehouse?</p>
# <ul>
#     <li>USAGE</li>
#     <li>MONITOR</li>
#     <li><b>MODIFY</b></li>
#     <li>ALTER</li>
# </ul>
#
# <p>For a multi-cluster virtual warehouse, what is the maximum number of clusters?</p>
# <ul>
#     <li>50</li>
#     <li>24</li>
#     <li>1</li>
#     <li><b>10</b></li>
# </ul>
#
# <p>In the Snowsight worksheet view, which of the following can be selected to set the context under which a query executes?</p>
# <ul>
#     <li>User</li>
#     <li><b>Role</b></li>
#     <li><b>Virtual Warehouse</b></li>
#     <li>Table</li>
#     <li><b>Schema</b></li>
#     <li><b>Database</b></li>
# </ul>
#
# <p>What role is required to enable replication for multiple accounts?</p>
# <ul>
#     <li>ACCOUNTADMIN</li>
#     <li>SYSADMIN</li>
#     <li><b>ORGADMIN</b></li>
#     <li>SECURITYADMIN</li>
# </ul>
#
# <p>Which of the following chart types are supported by Snowsight?</p>
# <ul>
#     <li>Pareto Charts</li>
#     <li>Area charts</li>
#     <li><b>Bar Charts</b></li>
#     <li><b>Pie Charts</b></li>
#     <li><b>Scorecards</b></li>
# </ul>
# <b>Explanation</b>
# <p>
# Snowsight supports</br>
# Bar charts,</br>
# Line charts,</br>
# Scatterplots,</br>
# Heat grids and</br>
# Scorecards</br>
# </p>
# <b>Explanation END</b><br>
#
# <p>Through Snowflake sharing, a data provider can share data with which of the following?</p>
# <ul>
#     <li>One Drive Users</li>
#     <li>Google Drive users</li>
#     <li><b>Another Snowflake customer</b></li>
#     <li><b>A non-Snowflake customer</b></li>
#     <li><b>Multiple Snowflake customers</b></li>
# </ul>
#
# <p>Which of the following can be fulfilled through the ACCESS_HISTORY view in the ACCOUNT_USAGE schema?</p>
# <ul>
#     <li><b>Help identify data that is unused and is not being queried.</b></li>
#     <li>Identify who logged into the system.</li>
#     <li>Identify which roles were used by the logged-in user</li>
#     <li><b>Identify what data was accessed, when, and who accessed it.</b></li>
# </ul>
#
# <p>Which of the following can be used to find the query ID of the most recent query executed in the current session?</p>
# <ul>
#     <li>SELECT LAST_QUERY_ID(2);</li>
#     <li>SELECT LAST_QUERY_ID(1);</li>
#     <li><b>SELECT LAST_QUERY_ID();</b></li>
#     <li><b>SELECT LAST_QUERY_ID(-1);</b></li>
#     <li>SELECT LAST_QUERY_ID(-2);</li>
# </ul>

# %% [markdown]
# <p>John, who has the SYSADMIN role, ran a query. Another user, Jane, attempts to view the result of the query executed by John using the Snowsight query history.</p>
# <ul>
#     <li><b>Jane can NOT see the result set of queries executed by John.</b></li>
#     <li>Jane can only see the result set of queries executed by John if John grants her permission.</li>
#     <li>Jane can see the result set of queries executed by John only if she is also part of the SYSADMIN role.</li>
#     <li>Jane can see the result set of queries executed by John only if she has the ACCOUNTADMIN role.</li>
# </ul>
#
# <p>Which of the following is true regarding Query Profile? Select all that apply.</p>
# <ul>
#     <li><b>It shows the query plan for a query.</b></li>
#     <li><b>It shows a graphical representation of all steps.</b></li>
#     <li><b>A query profile is available for all queries, whether running, completed, or failed.</b></li>
#     <li>A query profile is not available for queries that have not been completed.</li>
# </ul>
#
# <p>Which columns will be part of the result set when a directory table is queried?</p>
# <ul>
#     <li>IS_ENCRYPTED</li>
#     <li><b>ETAG</b></li>
#     <li><b>MD5</b></li>
#     <li>IS_DELETED</li>
#     <li><b>LAST_MODIFIED</b></li>
# </ul>
#
# <p>What of the following is true about the objects created by Partner Connect during the process of connecting to a partner?</p>
# <ul>
#     <li><b>The partner uses the PC_< partner >USER to connect to your Snowflake instance.</b></li>
#     <li>The PC< partner >DB database is only created if there is no other database in your system.</li>
#     <li><b>The PC< partner >DB database is empty and can be used to load or store data for querying.</b></li>
#     <li><b>The PC< partner >ROLE allows the partner application to access objects granted to the PUBLIC role.</b></li>
#     <li>The PC< partner >WH virtual warehouse is only created if there is no other virtual warehouse in your system.</li>
# </ul>
#
# <p>You are the owner of a table called CUSTOMER. The table is in the PUBLIC schema in the database called MARKETING. Which permissions do you need to provide on which objects to grant SELECT access to a role called ANALYST on the CUSTOMER table?</p>
# <ul>
#     <li>grant SELECT on schema PUBLIC to role ANALYST;</li>
#     <li><b>grant USAGE on schema PUBLIC to role ANALYST;</b></li>
#     <li>grant SELECT on database MARKETING to role ANALYST;</li>
#     <li><b>grant SELECT on table CUSTOMER to role ANALYST;</b></li>
#     <li><b>grant USAGE on database MARKETING to role ANALYST;</b></li>
#     <li>grant READ on schema PUBLIC to role ANALYST;</li>
# </ul>
#
# <p>Which of the following is true regarding Pre-signed URLs?</p>
# <ul>
#     <li><b>Pre-signed URLs are suitable to provide access to users & applications without needing authentication or authorization.</b></li>
#     <li><b>Anyone with a pre-signed URL can use the URL to access the referenced file.</b></li>
#     <li>A pre-signed URL expires after 24 hours.</li>
#     <li><b>The expiry time for a pre-signed URL can be configured.</b></li>
#     <li><b>A pre-signed URL is generated with an access token and can be accessed without requiring authentication.</b></li>
# </ul>
#
# <p>True or False: A share must have at least one consumer added.</p>
# <ul>
#     <li><b>False</b></li>
#     <li>True</li>
# </ul>
#
# <p>Which of the following are valid statements when loading data into a table (called EMPLOYEE) using the table stage?</p>
# <ul>
#     <li>COPY INTO EMPLOYEE FROM TABLE_STAGE;</li>
#     <li><b>COPY INTO EMPLOYEE;</b></li>
#     <li><b>COPY INTO EMPLOYEE FROM @%EMPLOYEE;</b></li>
#     <li>COPY INTO EMPLOYEE SELECT * FROM TABLE_STAGE;</li>
# </ul>
#
# <p>Once created, which of the following cannot be converted to any other table type?</p>
# <ul>
#     <li><b>Temporary</b></li>
#     <li><b>Transient</b></li>
#     <li>Permanent</li>
# </ul>
#
# <p>Which of the following can view and modify an existing resource monitor? Select all that apply.</p>
# <ul>
#     <li><b>A user who has MONITOR and MODIFY privilege on the resource monitor.</b></li>
#     <li><b>An account administrator (i.e., a person with the ACCOUNTADMIN role)</b></li>
#     <li>Any user of the system</li>
#     <li>A system administrator (i.e., a person with the SYSADMIN role).</li>
# </ul>

# %%
<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

<p></p>
<ul>
    <li></li>
    <li></li>
    <li></li>
    <li></li>
</ul>

# %% [markdown]
# <p>In Snowflake, which of the following types of URLs can be used to access unstructured data?</p>
# <ul>
# <li>Samba URL</li>
# <li>Network Share Path</li>
# <li><b>Pre-signed URL</b></li>
# <li><b>File URL</b></li>
# <li><b>Scoped URL</b></li>
# </ul>
#
# <p>Which of the following statements regarding built-in roles' privileges in Snowflake are true?</p>
# <ul>
# <li>The PUBLIC role can delete objects created by SYSADMIN</li>
# <li><b>SECURITYADMIN can drop USERS created by a USERADMIN</b></li>
# <li><b>ACCOUNTADMIN can modify a ROLE created by the SECURITYADMIN</b></li>
# <li><b>ACCOUNTADMIN can delete objects created by a SYSADMIN</b></li>
# </ul>
#
# <p>Which of the following are supported in Snowflake Scripting code?</p>
# <ul>
# <li><b>END</b></li>
# <li><b>DECLARE</b></li>
# <li><b>EXCEPTION</b></li>
# <li><b>BEGIN</b></li>
# <li>NOTIFY</li>
# <li>PARALLEL</li>
# </ul>
#
# <p>Which of the following roles can create & manage users? Select all that apply</p>
# <ul>
# <li>SYSADMIN</li>
# <li><b>ACCOUNTADMIN</b></li>
# <li><b>USERADMIN</b></li>
# <li><b>SECURITYADMIN</b></li>
# </ul>
#
# <p>Consider a database with the name MARKETING. The database has a table called CUSTOMER in the PUBLIC schema. The table has 10,000 rows.<br>
# You create a temporary table with the same name, i.e., CUSTOMER, in the PUBLIC schema of the MARKETING database. This temporary table has no data.</br>
# Which of the following statements correctly describes the behavior for SELECT queries (in the same session) accessing the CUSTOMER table?</p>
# <ul>
# <li>Executing "SELECT * FROM MARKETING.PUBLIC.CUSTOMER;" query returns 10,000 rows.</li>
# <li>Executing "SELECT * FROM MARKETING.PUBLIC.CUSTOMER;" query fails with a duplicate error.</li>
# <li>Executing "SELECT * FROM MARKETING.PUBLIC.CUSTOMER;" query fails with an unknown object error.</li>
# <li><b>Executing "SELECT * FROM MARKETING.PUBLIC.CUSTOMER;" query returns zero rows</b></li>
# </ul>
#
# <p>A multi-cluster virtual warehouse of size X-Large has 1 cluster running for 1 hour. Due to query demands, it scales out (adds another cluster) and then runs the two clusters for another house. What is the total number of credits consumed by the multi-cluster virtual warehouse?</p>
# <ul>
# <li>64</li>
# <li>16</li>
# <li><b>48</b></li>
# <li>32</li>
# </ul>
#
# <h4>Explanation</h4>
# <p>1 cluster of X-Large multi-cluster virtual warehouse running for 1 hour = 16 credits<br>
# 2 clusters of X-Large multi-cluster virtual warehouse running for 1 hour = 16 credits * 2 = 32<br>
# Total = 48</p>
# <h4>Explanation end </h4>
#
# <p>Which of the following can be enabled by an ORGADMIN using the SYSTEM$GLOBAL_ACCOUNT_SET_PARAMETER function?</p>
# <ul>
# <li>Time Travel</li>
# <li>Automatic Clustering</li>
# <li>Data Sharing</li>
# <li><b>Replication</b></li>
# <li><b>Client Redirect</b></li>
# </ul>
#
# <p>You are a telecom company's data engineer who uses Snowflake as a data warehouse. The company requires all network signaling data to be loaded into a table in near real-time. The network signaling data already lands into an S3 bucket every 1 minute. What is the course of action that you should take?</p>
# <ul>
# <li>Execute RUN Snowpipe to start the snowpipe</li>
# <li>Configure the Snowpipe to check for new files in the S3 bucket continuously.</li>
# <li><b>Configure the Snowpipe to check for new files in the S3 bucket continuously.</b></li>
# <li><b>Configure notification event on the S3 bucket, which triggers the Snowpipe.</b></li>
# <li><b>Create an external stage on top of the S3 bucket where the near real-time data lands.</b></li>
# </ul>
#
# <p>Which of the following objects may be shared via direct data sharing?</p>
# <ul>
# <li>Resource Monitors</li>
# <li>Virtual Warehouses</li>
# <li><b>Tables</b></li>
# <li><b>Secure UDFs</b></li>
# <li><b>External Tables</b></li>
# </ul>
#
# <p>To create an external UDF, what is the minimum Snowflake edition required?</p>
# <ul>
# <li>Enterprise</li>
# <li>Business Critical</li>
# <li>Virtual Private Snowflake</li>
# <li><b>Standard</b></li>
# </ul>

# %% [markdown]
# <p>Which of the following statements are true regarding Snowflake virtual warehouse's high availability?</p>
# <ul>
# <li><b>Snowflake will automatically replace failed compute instances within a virtual warehouse without causing disruptions.</b></li>
# <li>Snowflake replicates virtual warehouses across three availability zones.</li>
# <li>A failed virtual warehouse will result in corrupted data in tables.</li>
# <li><b>Snowflake can provision Virtual Warehouses in a different availability zone if required.</b></li>
# </ul>
#
# <h4>Explanation</h4>
# <p>
# Snowflake automatically & transparently replaces failed compute instances within a virtual warehouse. This occurs without disruption to any queries.<br>
# The compute layer, i.e., the virtual warehouses, is not replicated. The virtual warehouses do not permanently store data and thus don’t require replication.<br>
# Snowflake typically runs each virtual warehouse in a single availability zone. However, in case of an availability zone failure, Snowflake’s cloud services layer can re-provision impacted warehouses in a different availability zone.<br>
# https://developers.snowflake.com/wp-content/uploads/2021/06/Snowflake-High-Availability-for-Data-Apps-Whitepaper.pdf</p>
# <b>Explanation</b>
#
# <p>Which of the following statements best describe Snowflake's access control mechanism? Select all that apply.</p>
# <ul>
# <li><b>Roles can be granted to other users</b></li>
# <li>Roles can NOT be granted to other roles</li>
# <li><b>Privileges can be granted on securable objects</b></li>
# <li><b>Roles can be granted to other roles</b></li>
# </ul>
#
# <p>Which of the following correctly describes the behaviour when a Transient table is attempted to be cloned?</p>
# <ul>
# <li>Transient tables can be cloned to external tables.</li>
# <li>Transient tables can be cloned to permanent tables</li>
# <li><b>Transient tables can be cloned to transient tables.</b></li>
# <li><b>Transient tables can be cloned to temporary tables.</b></li>
# </ul>
#
# <p>Which of the following allows users to control how the data for a table is organized in micro-partitions?</p>
# <ul>
# <li><b>Automatic Clustering</b></li>
# <li>Partition Pruning</li>
# <li>Search Optimization</li>
# <li>Materialized Views</li>
# </ul>
#
# <p>After a virtual warehouse has been suspended by a resource monitor, which of the following will allow the virtual warehouse to be resumed?</p>
# <ul>
# <li>An account administrator resumes the virtual warehouse.</li>
# <li>The virtual warehouse is resumed using SnowSQL.</li>
# <li><b>The next interval for the resource monitor starts.</b></li>
# <li>The monitor's credit quota is increased.</li>
# <li><b>The credit threshold for the suspend action is increased.</b></li>
# </ul>
#
# <p>Which of the following terms may be used to describe Snowflake?</p>
# <ul>
# <li>Shared Disk</li>
# <li><b>Shared Data</b></li>
# <li><b>Native SQL support</b></li>
# <li><b>Built from scratch, specifically designed for execution on cloud platforms.</b></li>
# <li>Shared Compute</li>
# <li><b>Hybrid Columnar Storage</b></li>
# </ul>
#
# <p>You can upload data into which of the following stages using the PUT command? Select all that apply.</p>
# <ul>
# <li><b>Named Internal Stage</b></li>
# <li>External Stage</li>
# <li><b>Table Stage</b></li>
# <li><b>User Stage</b></li>
# </ul>
#
# <p>What S3 permissions are required when unloading data from Snowflake to an AWS 3 location?</p>
# <ul>
# <li><b>s3:DeleteObject</b></li>
# <li>s3:ListBucket</li>
# <li><b>s3:PutObject</b></li>
# <li>s3:GetObject</li>
# </ul>
#
# <p>***Which of the following correctly describes the behavior of a materialized view when new columns are added to the base table?</p>
# <ul>
# <li>The materialized view is suspended</li>
# <li><b>The new columns are NOT propagated to the materialized view automatically.</b></li>
# <li><b>The materialized view is NOT suspended.</b></li>
# <li>You must resume the materialized view if you want to use it again.</li>
# <li>The new columns are automatically propagated to the materialized view.</li>
# </ul>
#
# <p>Which of the following statements are true regarding URL expiry?</p>
# <ul>
# <li><b>Scoped URLs expire after 24 hours.</b></li>
# <li><b>File URLs never expire.</b></li>
# <li>File URLs expire after 24 hours.</li>
# <li>Scoped URLs don't expire.</li>
# </ul>

# %% [markdown]
# <p>Columns with which data types can be used as clustering keys?</p>
# <ul>
# <li>GEOGRAPHY</li>
# <li>VARIANT</li>
# <li>OBJECT</li>
# <li><b>BINARY</b></li>
# <li><b>GEOMETRY</b></li>
# </ul>
#
# <p>True or False: A database is created from a share by the consuming account; the access to this database is configurable using Snowflake's role-based access control.</p>
# <ul>
# <li>True</li>
# <li><b>False</b></li>
# </ul>
#
# <p>Which of the following actions can NOT be performed by a consumer account on a shared database?</p>
# <ul>
# <li><b>Modify data in a shared table</b></li>
# <li>Query data in a shared table</li>
# <li><b>Use Time Travel on shared tables.</b></li>
# <li>Join data from a shared table with another table</li>
# <li><b>Clone the shared database</b></li>
# <li><b>Clone a table from the shared database</b></li>
# </ul>
#
# <p>You are required to regularly refresh the metadata for a directory table for an external stage. Which of the following methods can you use?</p>
# <ul>
# <li><b>Configure even notifications on the cloud platform and set the stage to auto-refresh</b></li>
# <li>Request Snowflake support to refresh the stage periodically.</li>
# <li>Configure a Resource Monitor to refresh the stage periodically.</li>
# <li><b>Run ALTER STAGE < stage-name > REFRESH; periodically to manually refresh the metadata</b></li>
# </ul>
#
# <p>Which of the following objects can be cloned? Select all that apply.</p>
# <ul>
# <li><b>Table</b></li>
# <li>Virtual Warehouse</li>
# <li><b>Schema</b></li>
# <li>Share</li>
# <li><b>Task</b></li>
# <li><b>Database</b></li>
# </ul>
#
# <p>Which of the following is true regarding stored procedures?</p>
# <ul>
# <li><b>A newly created stored procedure defaults to run under the owner's privileges.</b></li>
# <li><b>A stored procedure can be altered to configure if it runs under owner's rights or caller's rights.</b></li>
# <li>Once created, a stored procedure can not be altered to configure if it runs under owner's rights or caller's rights</li>
# <li>A newly created stored procedure defaults to run under the caller's privileges</li>
# </ul>
#
# <p>Under which circumstances will the query result cache fulfill the query result? Select all that apply</p>
# <ul>
# <li>New micro-partitions have been added to one of the tables used in the query.</li>
# <li><b>The micro-partitions for the tables in the query have not changed.</b></li>
# <li>The query is executed by the same user who generated the result cache for a previous query.</li>
# <li><b>The query matches a previously executed query for which cached results are still available.</b></li>
# <li><b>The role executing the query has the necessary privileges on the tables used in the query.</b></li>
# </ul>
#
# <p>Which of the following ACCOUNT_USAGE view can be used to view credit usage by hour?</p>
# <ul>
# <li><b>METERING_HISTORY</b></li>
# <li>METERING_DAILY_HISTORY</li>
# <li>WAREHOUSE_EVENTS_HISTORY</li>
# <li>WAREHOUSE_LOAD_HISTORY</li>
# </ul>
#
# <p>Basic Transformations during the COPY process are supported by which of the following stage types?</p>
# <ul>
# <li><b>Named Internal Stage</b></li>
# <li><b>External Stage</b></li>
# <li>Table Stage</li>
# </ul>
#
# <p>A multi-clustered virtual warehouse is configured in Auto Scaling mode. Which of the following Scaling Policies does it support? Select two options.</p>
# <ul>
# <li><b>Standard</b></li>
# <li><b>Echonomy</b></li>
# <li>Efficient</li>
# <li>Fast</li>
# </ul>

# %%
<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

<p></p>
<ul>
<li></li>
<li></li>
<li></li>
<li></li>
</ul>

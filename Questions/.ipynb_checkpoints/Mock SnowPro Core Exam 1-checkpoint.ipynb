# %% [markdown]
# <p>Which of the following tool is used for connectivity diagnostics?</p>
# <ul>
# <li><b>SnowCD</b></li>
# <li>SnowSQL</li>
# <li>Snowpipe</li>
# <li>Snowsight</li>
# </ul>
#
# <p>You are required to see the query history for a date seven months ago. Which of the following methods will provide you with the query history for seven months ago?</p>
# <ul>
# <li>View the historical queries using the query history page</li>
# <li>Request Snowflake support to provide query history</li>
# <li>Use the QUERY_HISTORY table function in the INFORMATION schema</li>
# <li><b>Use the QUERY_HISTORY view in the ACCOUNT_USAGE schema</b></li>
# </ul>
#
#
# <p>What is the maximum duration of Time Travel allowed in the Snowflake Standard edition?</p>
# <ul>
# <li><b>1 day</b></li>
# <li>0 days</li>
# <li>45 days</li>
# <li>90 days</li>
# </ul>
#
#
# <p>You can upload data into which of the following stages using the PUT command? Select all that apply.</p>
# <ul>
# <li>External Stage</li>
# <li><b>User Stage</b></li>
# <li><b>Named Internal Stage</b></li>
# <li><b>Table Stage</b></li>
# </ul>
#
#
# <p>Which of the following privileges allows a user in a consumer account to create a database from a share? Select two.</p>
# <ul>
# <li>SYSADMIN role</li>
# <li>SECURITY ADMIN role</li>
# <li><b>IMPORT SHARE privileges</b></li>
# <li><b>ACCOUNTADMIN role</b></li>
# </ul>
#
#
# <p>The cloud services layer in Snowflake provides which of the following? Select all that apply.</p>
# <ul>
# <li><b>Authentication</b></li>
# <li><b>Query Optmization</b></li>
# <li>Query Execution</li>
# <li><b>Query Planning</b></li>
# <li><b>Authorization</b></li>
# </ul>
#
# <p>Basic Transformations during the COPY process are supported by which of the following stage types?</p>
# <ul>
# <li><b>External Stage</b></li>
# <li>Table Stage</li>
# <li><b>Named Internal Stage</b></li>
# </ul>
#
#
# <p>What are some of the ways to improve performance in Snowflake? Select all that apply</p>
# <ul>
# <li><b>Multi-cluster Virtual Warehouse</b></li>
# <li><b>Dedicated Virtual Warehouse<b></li>
# <li>Secondary Indices</li>
# <li><b>Clustering Keys</b></li>
# <li><b>Query Result Caching</b></li>
# </ul>
#
#
# <p>***Which of the following can be used to download data from an external stage to an on-premises system?</p>
# <ul>
# <li>GET</li>
# <li><b>Cloud Provider Utilities</b></li>
# <li>PUT</li>
# <li>COPY</li>
# </ul>
#
#
# <p>True or False: An ACCOUNTADMIN can see the results of any query executed by any user in a Snowflake system.
# </p>
# <ul>
# <li><b>False</b></li>
# <li>True</li>
# </ul>
#
#
# <p>What is the minimum Snowflake edition that supports Tri-Secret Secure encryption?</p>
# <ul>
# <li>Virtual Private Snowflake</li>
# <li><b>Business Crirital</b></li>
# <li>Enterprise</li>
# <li>Standard</li>
# </ul>
#
# <p>Which of the following are ways to see a history of the queries executed on a Snowflake account?</p>
# <ul>
# <li>Request Snowflake support to provide history</li>
# <li><b>Use the QUERY_HISTORY vieww in the ACCOUNT_USAGE schema</b></li>
# <li><b>View the historical queries using the query hstory page</b></li>
# <li><b>Use the QUERY_HISTORY table function in the INFORMATION schema</b></li>
# </ul>
#
# <p>External tables are a good solution for which of the following is true? Select all that apply.</p>
# <ul>
# <li><b>Typically only a subset of Data is accessed</b></li>
# <li><b>Data is already in a data lake on a cloud platform (e.g S3, Azure Blob Storage, Google storage)</b></li>
# <li><b>The data is not accessed frequently</b></li>
# <li>Data is in binary format and can not be loaded into Snowflake</li>
# </ul>
#
#
# <p>Which of the following semi-structured file formats are supported by Snowflake? Select all that apply</p>
# <ul>
# <li><b>JSON</b></li>
# <li><b>PARQUET</b></li>
# <li>HTML</li>
# <li>YAML</li>
# <li><b>XML</b></li>
# </ul>
#
#
# <p>A virtual warehouse has been scaled down. When are nodes removed from the virtual warehouse?</p>
# <ul>
# <li>When the virtual warehouse is suspended</li>
# <li>After 60 seconds</li>
# <li>Immediately</li>
# <li><b>After all existing active queries have finished executing</b></li>
# </ul>
#
# <p>Under which circumstance will the query result cache fulfill the query result? Select all that apply</p>
# <ul>
# <li>The query returns a result set of fewer than 100 thousand rows.</li>
# <li>The query is being executed from the same virtual warehouse as the previously executed query.</li>
# <li><b>The micro-partitions for the tables in the query have not changed.</b></li>
# <li><b>The query results cache was generated or used less than 24 hours ago.</b></li>
# <li><b>The role executing the query matches the role that generated the previous results.</b></li>
# </ul>
#
#
# <p>True or False: The COPY command exports to a single file by default.</p>
# <ul>
# <li><b>True</b></li>
# <li>False</li>
# </ul>
#
# <p>Is it possible to share data with a Snowflake customer whose Snowflake instance exists in a different cloud platform than the data provider?</p>
# <ul>
# <li>
# No, sharing with customers in other cloud platforms is not possible</li>
# <li><b>Yes, but to enable data sharing to a different cloud platform, you must enable replication first.</b></li>
# <li>
# Yes. Nothing special needs to be done to enable cross-cloud platform data sharing.</li>
# </ul>
#
#
# <p>For which one of the following scenarios, Scaling Out a virtual warehouse, is a good option?</p>
# <ul>
# <li>
# There is an increase in query complexity.</li>
# <li><b>
# There are more active concurrent queries than the current virtual warehouse can handle</b></li>
# <li>The query uses a materialized view.</li>
# <li>A query is accessing more than 5 tables.</li>
# </ul>
#
#
# <p>Which one of the following objects can NOT be cloned?</p>
# <ul>
# <li><b>Named Internal Stage</b></li>
# <li>External Stage</li>
# <li>Databases</li>
# <li>Schemas</li>
# </ul>
#
# <p>Which of the following statements accurately describes Snowflake's encryption for data at rest? Select all that apply.</p>
# <ul>
#     <li><b>Snowflake rekeys encrypted data after 1 year</b></li>
#     <li><b>Every 30 days, Snowflake rotates the keys used for encryption</b></li>
#     <li><b>Snowflake manages encryption keys by default</b></li>
# <li>Snowflake uses AES - 128-bit encryption to encrypt data at rest</li>
# </ul>
#
# <p>Which of the following statements best describe Snowflake's federated authentication? Select all that apply</p>
# <ul>
# <li>After being authorized by an external identity source, users must enter their Snowflake username and password</li>
# <li><b>Snowflake is compatible with the majority of SAML 2.0 identity providers</b></li>
# <li><b>Snowflake has native support for Okta and ADFS.</b></li>
# <li><b>
# Once authenticated with an external identity provider, a user is not required to submit their Snowflake username & password individually.</b></li>
# </ul>
#
#
# <p>What can you expect if the filters specified in an INFORMATION_SCHEMA query are not sufficiently selective?</p>
# <ul>
# <li><b>Error</b></li>
# <li>Warning</li>
# <li>Success</li>
# <li>Empty resultset</li>
# </ul>
#
#
# <p>When creating a clustering key with multiple columns, in what order should the columns be specified in the CLUSTER BY clause?</p>
# <ul>
# <li><b>Lowest cardinality to highest cardinality</b></li>
# <li>Highest cardinality to lowest cardinality</li>
# <li>Reverse alphabetical order</li>
# <li>The order does not matter</li>
# <li>Alphabetical order</li>
# </ul>
#
#
# <p>Snowflake provides which of the following drivers?</p>
# <ul>
# <li><b>
# JDBC driver for Snowflake</b></li>
# <li><b>.NET driver for Snowflake</b></li>
# <li><b>PHP PDO driver</b></li>
# <li><b>Snowflake driver for the Go language</b></li>
# <li><b>ODBC driver for Snowflake</b></li>
# </ul>
#
#
# <p>Which of the following statements correctly describe Search Optimization in Snowflake? Select all that apply.</p>
# <ul>
# <li><b>The search optimization configuration on a table and its maintenance service are transparent to the users.</b></li>
# <li>The search optimization service doesn't use a persistent data structure.</li>
# <li><b>The search optimization service uses a persistent data structure</b></li>
# <li></li>
# </ul>
#
#
# <p>Which of the following are the types of releases that Snowflake deploys weekly? Select two answers.</p>
# <ul>
# <li><b>Full Release</b></li>
# <li>Alpha Release</li>
# <li><b>Patch Release</b></li>
# <li>Beta Release</li>
# </ul>
#
#
# <p>When cloning a table, your current role must have which privilege on the source table?</p>
# <ul>
# <li><b>USAGE</b></li>
# <li>WRITE</li>
# <li><b>SELECT</b></li>
# <li></li>
# </ul>
#
#
# <p>The COPY command allows the following options for selecting files for loading data from a stage.</p>
# <ul>
# <li><b>Load files that match a pattern.</b></li>
# <li><b>Load all files in a specific path.</b></li>
# <li><b>Load specific files by providing exact file names.</b></li>
# </ul>
#
#
# <p>Which of the following statements are true regarding External Tables? Select all that apply.</p>
# <ul>
# <li>An external table can not be queried.</li>
# <li><b>An external table can be joined with other tables</b></li>
# <li>An externla table can not be joined with other tables</li>
# <li><b>You can query an external table just like a regular table</b></li>
# </ul>
#
#
# <p>What is the minimum Snowflake edition required to browse Snowflake Marketplace?</p>
# <ul>
# <li>Standard</li>
# <li><b>You dont need a Snowflake edition to brows the Snowfalke market place listings</b></li>
# <li>Enterprise</li>
# <li>Virtual Private Snowflake</li>
# <li>Business Critical</li>
# </ul>
#
#
# <p>Which of the following criteria must be met for Snowflake to reuse the query result cache for a query? Choose all that apply.</p>
# <ul>
# <li><b>The query does not make use of runtime functions.</b></li>
# <li><b>The table micro-partitions have NOT altered as a result of reclustering or consolidation.</b></li>
# <li><b>A new query matches an old query.</b></li>
# <li><b>The query makes no use of user-defined or external functions.</b></li>
# <li><b>The underlying data that contributes to the query results has remained unchanged.</b></li>
# </ul>
#
#
# <p>Which of the following statement is correct regarding Snowflake billing? Select all that apply.</p>
# <ul>
# <li>Snowflake billing is based on the amount of data processed by queries</li>
# <li><b>Snowflake billing is based on the amount of data processed by queries</b></li>
# <li><b>Snowflake billing is based on the actual used storage.</b></li>
# <li>Snowflake billing is based on the number of queries executed.</li>
# </ul>
#
#
# <p>During a weekly release cycle, which of the following accounts may be updated on the second day of release?</p>
# <ul>
# <li><b>All standard edition accounts</b></li>
# <li><b>
# All enterprise edition (and above) accounts that have not opted into early access</b></li>
# <li>All business critical edition accounts</li>
# <li>Only those Enterprise edition accounts which have opted into early access</li>
# </ul>
#
# <p>A stored procedure has been set up as a stored procedure with owner's rights. A system administrator runs the stored procedure. Which of the following statement correctly describes how the stored procedure will execute?</p>
# <ul>
# <li>The stored procedure executes with ACCOUNTADMIN role permissions.</li>
# <li>The stored procedure executes using the privileges of the users executing the stored procedure.</li>
# <li><b>The stored procedure executes using the privileges of the role owning the stored procedure.</b></li>
# <li>The stored procedure executes with SYSADMIN role permissions.</li>
# </ul>
#
# <p>Which of the following statement is true regarding key pair authentication in Snowflake? Select all that apply.</p>
# <ul>
# <li>
# Key pair authentication requires the user to provide a password.</li>
# <li>Key pair authentication enables single sign-on (SSO).</li>
# <li><b>Key pair authentication is an alternative to simple username/password authentication.</b></li>
# <li><b>Key pair authentication consists of a private key and one or two public keys.</b></li>
# </ul>
#
# <p>Which of the following correctly describes a materialized view? Select all that apply.</p>
# <ul>
# <li>A materialized view re-computes its results every time a query uses the materialized view.</li>
# <li><b>A materialized view pre-computes the results of an SQL statement.</b></li>
# <li>A materialized view is like a secondary index.</li>
# <li><b>A materialized view physically stores the results</b></li>
# </ul>
#
#
# <p>Snowflake provides which of the following connectors?</p>
# <ul>
# <li><b>Snowflake Connector for Kafka</b></li>
# <li><b>Snowflake Connector for Python</b></li>
# <li>Snowflake Connector for Cobol</li>
# <li><b>Snowflake Connector for Spark</b></li>
# <li>Snowflake Connector for Assembly</li>
# </ul>
#
# <p>Which of the following Snowflake editions support database failover and failback between Snowflake accounts, thus providing business continuity and disaster recovery? Select all that apply.</p>
# <ul>
# <li>Standard</li>
# <li>Enterprise</li>
# <li><b>Virtual Private Snowflake</b></li>
# <li><b>Business Critical</b></li>
# </ul>
#
#
# <p>What does Tri-Secret Secure encryption in Snowflake provide? Choose two.</p>
# <ul>
# <li><b>Tri-Secret Secure allows customers to bring their own keys for encryption</b></li>
# <li><b>Tri-Secret Secure requires the Business Critical edition or higher.</b></li>
# <li>Tri-Secret Secure requires the Enterprise edition or higher</li>
# <li>Tri-Secret Secure provides multi-factor authentication capabilities in Snowflake.</li>
# </ul>
#
# <p>Can files already processed into the source table be loaded again into a cloned table?</p>
# <ul>
# <li><b>Yes</b></li>
# <li>No</li>
# </ul>
#
# <p>What is the minimum Snowflake edition that supports a dedicated metadata store?</p>
# <ul>
# <li><b>Virtual Private Snowflake</b></li>
# <li>Enterprise</li>
# <li>Standard</li>
# <li>Business Critical</li>
# </ul>
#
# <p>True or False: The functions provided in INFORMATION_SCHEMA can be used to view account-level information.</p>
# <ul>
# <li><b>False</b></li>
# <li>True</li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>

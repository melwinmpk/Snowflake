# %% [markdown]
# <p>Which of the following is true regarding how table columns are stored in Snowflake? Select all that apply.</p>
# <ul>
# <li><b>Snowflake determines the best compression algorithm for each column automatically.</b></li>
# <li><b>Columns are stored in columnar format within each micro-partition.</b></li>
# <li><b>Storing data in columnar format allows Snowflake to eliminate unnecessary columns during query execution.</b></li>
# <li><b>Data in each column is individually compressed.</b></li>
# </ul>
#
# <p>True or False: A Snowflake customer can share data with a data consumer in a different cloud platform/region without replicating data.</p>
# <ul>
# <li><b>False</b></li>
# <li>True</li>
# </ul>
#
# <p>True or False: Snowflake supports only Scalar external functions?</p>
# <ul>
# <li>False</li>
# <li><b>True</b></li>
# </ul>
#
# <p>What is the minimum Snowflake edition required to use the Search Optimisation service for point lookup queries?</p>
# <ul>
# <li>Stndard</li>
# <li>Business Critical</li>
# <li><b>Enterprise</b></li>
# <li>VPS</li>
# </ul>
#
# <p>Using Time Travel SQL, which of the following can be performed by a user?</p>
# <ul>
# <li>Retrieve data as it will exist in the future.</li>
# <li><b>Retrieve data as it was before a timestamp.</b></li>
# <li>Retrieve data as it existed 365 days ago.</li>
# <li><b>Retrieve data as it was before a query was executed.</b></li>
# </ul>
#
# <p>Which of the following columns will be part of the result set when a directory table is queried?</p>
# <ul>
# <li><b>RELATIVE_PATH</b></li>
# <li>ENCRYPTION_KEY</li>
# <li><b>SIZE</b></li>
# <li><b>FILE_URL</b></li>
# <li>IS_COMPRESSED</li>
# </ul>
#
# <p>True or False: Network policies in Snowflake currently support only IPv4.</p>
# <ul>
# <li>False</li>
# <li><b>True</b></li>
# </ul>
#
# <p>What of the following is true about the virtual warehouse created by Partner Connect during the process of connecting to a partner?</p>
# <ul>
# <li>The size of the virtual warehouse defaults to 6X-Large.</li>
# <li><b>The virtual warehouse size can be changed if required.</b></li>
# <li><b>The size of the virtual warehouse defaults to X-Small.</b></li>
# <li>The virtual warehouse size can NOT be changed once created.</li>
# </ul>
#
#
# <p>Which of the following activities are not required to be performed by a Snowflake customer?</p>
# <ul>
# <li>Management of user access & privileges</li>
# <li><b>Provision hardware for installing the Snowflake database</b></li>
# <li><b>Configuration and Testing of High availability of hardware at the data center level</b></li>
# <li><b>Installation of Snowflake Software</b></li>
# </ul>
#
#
# <p>Which ACCOUNT_USAGE view provides information about which tables & columns were read by queries in the last 12 months?</p>
# <ul>
# <li>QUERY_HISTORY</li>
# <li><b>ACCESS_HISTORY</b></li>
# <li>WAREHOUSE_EVENTS_HISTORY</li>
# <li>METERING_HISTORY</li>
# </ul>
#
# <p>Which of the following aspects are considered for calculating the storage costs for a Snowflake account?</p>
# <ul>
# <li><b>The daily average of storage used during the month.</b></li>
# <li>Un-compressed data</li>
# <li>The amount of data stored as of the end of the month.</li>
# <li><b>Compressed data</b></li>
# <li>The aggregated amount of storage used during the month.</li>
# </ul>
#
# <p>What privileges are required for a user to add or remove the search optimization for a table?</p>
# <ul>
# <li>ORGADMIN privileges</li>
# <li>SECURITYADMIN privileges</li>
# <li>SYSADMIN privileges</li>
# <li><b>ADD SEARCH OPTIMIZATION on the schema that contains the table</b></li>
# <li>UPDATE privileges on the table</li>
# <li><b>OWNERSHIP privileges on the table</b></li>
# </ul>
#
# <p>Which of the following illustrations represent the tables that have the same clustering depth? Select all that apply. </p>
# <img src='https://github.com/melwinmpk/SCD_in_Warehouse/assets/25386607/63911f5c-75e1-4cef-ad91-86a5108abf41'>
# <ul>
# <li>1</li>
# <li><b>3</b></li>
# <li><b>4</b></li>
# <li><b>2</b></li>
# </ul>
#
# <p>Which of the following Single Sign-on workflows may be performed by using federated authentication?</p>
# <ul>
# <li><b>System timeout due to inactivity</b></li>
# <li><b>Logging into Snowflake</b></li>
# <li>Role Authorization</li>
# <li>User Authorization</li>
# <li>Row-level Security</li>
# <li><b>Logging out of Snowflake</b></li>
# </ul>
#
# <p>True or False: Snowpark can push down your user-defined functions to the database server, where the code then operates on the data.</p>
# <ul>
# <li>False</li>
# <li><b>True</b></li>
# </ul>
#
# <p>What role is required to execute the following statements to enable replication?</p>
# <pre>
# SELECT SYSTEM$GLOBAL_ACCOUNT_SET_PARAMETER('myorg.acct1','ENABLE_ACCOUNT_DATABASE_REPLICATION', 'true');
#
# SELECT SYSTEM$GLOBAL_ACCOUNT_SET_PARAMETER('myorg.acct2','ENABLE_ACCOUNT_DATABASE_REPLICATION', 'true');
# </pre>
# <ul>
# <li>ACCOUNTADMIN</li>
# <li>SYSADMIN</li>
# <li><b>ORGADMIN</b></li>
# <li>SECURITYADMIN</li>
# </ul>
#
# <p>Which ACCOUNT_USAGE view can be used to identify the most frequently accessed tables?</p>
# <ul>
# <li><b>ACCESS_HISTORY</b></li>
# <li>QUERY_HISTORY</li>
# <li>DATABASE_STORAGE_USAGE_HISTORY</li>
# <li>OBJECT_DEPENDENCIES</li>
# </ul>
#
# <p>Consider a Snowflake account hosted on the AWS platform. An external table created on this account can read data from which of the following?</p>
# <ul>
# <li><b>Azure Blob Storage</b></li>
# <li>On-premises SQL server files</li>
# <li><b>Amazon S3</b></li>
# <li><b>Google Cloud Storage</b></li>
# <li>On-premises Postgres data files</li>
# </ul>
#
# <p>Which of the following is true regarding Scoped URLs?</p>
# <ul><li><b>A scoped URL is a temporary, encoded URL that enables access to a staged file without requiring privileges on the stage.</b></li>
# <li><b>Only the user who generates a scoped URL can use the URL to access the referenced file.</b></li>
# <li><b>Scoped URLs are suitable to provide temporary access for a user or an application.</b></li>
# <li><b>A scoped URL expires after 24 hours.</b></li>
# </ul>
#
# <p>Which of the following table types are not protected by fail-safe storage? Select all that apply.</p>
# <ul>
# <li><b>Transient</b></li>
# <li><b>Temporary</b></li>
# <li>Clustered</li>
# <li>Permanent</li>
# </ul>

# %% [markdown]
# <p>Which of the following Snowflake Editions support search optimization service for opitmizing point look up queries?</p>
# <ul>
# <li><b>Business Critical Edition</b></li>
# <li>Standard Edition</li>
# <li><b>Virtual Private Snowflake (VPS) edition</b></li>
# <li><b>Enterprise Edition</b></li>
# </ul>
#
# <p>What kind of partner are Alation, Immuta, and Collibra in the Snowflake partner ecosystem?</p>
# <ul>
# <li>Machine Learning & Data Science</li>
# <li>Data Integration</li>
# <li>SQL Development and Management</li>
# <li><b>Security, Governance & Observability</b></li>
# </ul>
#
#
# <p>Which of the following statement is correct regarding clustering?</p>
# <ul>
# <li><b>A clustering key can have more than one column.</b></li>
# <li>A clustering key can only contain date columns.</li>
# <li><b>Defining a clustering key is not mandatory.</b></li>
# <li>A clustering key must be defined for each table.</li>
# <li>A table can have more than one clustering key.</li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
#
# <p></p>
# <ul>
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>

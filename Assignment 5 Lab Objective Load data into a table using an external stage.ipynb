# %% [markdown]
# <div class="practice--panel--ejs8J"><div data-purpose="practice-component-text" class="rt-scaffolding"><h4>Lab Objective: Load data into a table using an external stage</h4><p>This lab guides you through the process of loading data into a Snowflake table using an external stage. The external stage in this example will point to data in an S3 bucket.</p><p><br></p><ol><li><p>Create a new database in your Snowflake instance by the name of dev_lnd. We have used the dev_lnd naming convention to represent the landing database in the development environment. We will use this database for loading data.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">CREATE DATABASE dev_lnd</span><span class="pun">;</span></li></ol></pre></div></div><p><br></p></li><li><p>In the dev_lnd database, create a new table by the name of Flight_Details. </p><p><br></p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE DATABASE dev_lnd</span><span class="pun">;</span></li><li class="L1"><span class="pln">USE SCHEMA </span><span class="kwd">public</span><span class="pun">;</span></li><li class="L2"><span class="pln">&nbsp;</span></li><li class="L3"><span class="pln">CREATE TABLE </span><span class="typ">Flight_Details</span></li><li class="L4"><span class="pun">(</span></li><li class="L5"><span class="typ">Flight_Date</span><span class="pln"> </span><span class="typ">Date</span><span class="pun">,</span></li><li class="L6"><span class="typ">Airline_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pln"> </span><span class="pun">,</span></li><li class="L7"><span class="typ">Airline_DOT_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L8"><span class="typ">Airline_IATA_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L9"><span class="typ">Airline_Tail_Number</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L0"><span class="typ">Airline_Flight_Number</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L1"><span class="typ">Origin_Airport_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L2"><span class="typ">Origin_Airport_SEQ_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L3"><span class="typ">Origin_City_Market_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L4"><span class="typ">Origin_Airport_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L5"><span class="typ">Origin_State_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L6"><span class="typ">Origin_State_FIPS</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L7"><span class="typ">Origin_Airport_WAC</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L8"><span class="typ">Destintation_Airport_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L9"><span class="typ">Destintation_Airport_SEQ_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L0"><span class="typ">Destintation_City_Market_ID</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L1"><span class="typ">Destination_Airport_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L2"><span class="typ">Dest_State_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L3"><span class="typ">Dest_State_FIPS</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L4"><span class="typ">Dest_Airport_WAC</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L5"><span class="typ">Departure_Time</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L6"><span class="typ">Departure_Delay_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L7"><span class="typ">Departure_Taxi_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L8"><span class="typ">Departure_Wheels_Off_Time</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L9"><span class="typ">Arrival_Wheels_On_Time</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L0"><span class="typ">Arrival_Taxi_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L1"><span class="typ">Arrival_Time</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L2"><span class="typ">Arrival_Delay</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L3"><span class="typ">Flight_Cancelled_Indicator</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L4"><span class="typ">Flight_Cancellation_Code</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L5"><span class="typ">Flight_Diverted_Indicator</span><span class="pln"> </span><span class="typ">String</span><span class="pun">,</span></li><li class="L6"><span class="typ">Flight_Total_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L7"><span class="typ">Flight_In_Air_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L8"><span class="typ">Number_Of_Flights</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L9"><span class="typ">Total_Distance</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L0"><span class="typ">Carrier_Delay_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L1"><span class="typ">Weather_Delay_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L2"><span class="pln">NAS_Delay_Duration </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L3"><span class="typ">Security_Delay_Duration</span><span class="pln"> </span><span class="typ">Number</span><span class="pun">,</span></li><li class="L4"><span class="typ">Late_Aircraft_Delay_Duration</span><span class="pln"> </span><span class="typ">Number</span></li><li class="L5"><span class="pun">);</span><span class="pln"> </span></li></ol></pre></div></div><p><br></p></li><li><p>Download the data for the Flight_Details table from <a target="_blank" rel="noopener noreferrer" href="https://ca-flight-data-daily.s3.amazonaws.com/2020/06/01/flights_data_20200601.csv">https://ca-flight-data-daily.s3.amazonaws.com/2020/06/01/flights_data_20200601.csv</a></p><p><br></p><p>Note that the file contains data for 1st June 2020 only. We will be using different techniques to load data for other days &amp; months in future exercises. </p><p><br></p></li><li><p>Download the above file, store it in a folder and familiarize yourself with the structure. The file is a CSV file with several columns, where values are comma-separated and are enclosed in double quotes.</p><p><br></p><p><strong><em>Note that the above S3 bucket has been made public to simplify the process of loading data. If you are loading data from a secured bucket, we cover additional security access configuration steps in a separate future exercise. </em></strong></p><p><br></p></li><li><p>Let us create the external stage pointing to the above location. When creating an external stage, you will use the S3 URI rather than the HTTP version shown in the previous step. The S3 URI for the folder containing the above file is s3://ca-flight-data-daily/2020/06/01/</p><p><br></p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">CREATE OR REPLACE STAGE flights_stage</span></li><li class="L1"><span class="pln"> url</span><span class="pun">=</span><span class="str">'s3://ca-flight-data-daily/2020/06/01/'</span></li><li class="L2"><span class="pln"> file_format </span><span class="pun">=</span><span class="pln"> </span><span class="pun">(</span><span class="pln">type </span><span class="pun">=</span><span class="pln"> </span><span class="str">'CSV'</span><span class="pln"> field_delimiter </span><span class="pun">=</span><span class="pln"> </span><span class="str">','</span><span class="pln"> field_optionally_enclosed_by </span><span class="pun">=</span><span class="pln"> </span><span class="str">'"'</span><span class="pln"> skip_header </span><span class="pun">=</span><span class="pln"> </span><span class="lit">1</span><span class="pun">);</span></li></ol></pre></div></div><p><br></p></li><li><p>Next, we list the content of the external stage and validate that we can see the files contained in the external stage. To do so run the LIST command.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">LIST </span><span class="lit">@flights_stage</span><span class="pun">;</span></li></ol></pre></div></div><p>You should see the following file listed </p><p>s3://ca-flight-data-daily/2020/06/01/flights_data_20200601.csv</p><p><br></p></li><li><p>Let us now load the data into the Flight_Details table from the external stage. We will use the COPY command to load the data from the external stage. Notice that we have not specified a file format, as we already specified a file format when creating the external stage. </p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE DATABASE dev_lnd</span><span class="pun">;</span></li><li class="L1"><span class="pln">COPY INTO </span><span class="typ">Flight_Details</span></li><li class="L2"><span class="pln">  FROM </span><span class="lit">@flights_stage</span></li><li class="L3"><span class="pln">  PATTERN </span><span class="pun">=</span><span class="pln"> </span><span class="str">'.*[.]csv'</span><span class="pun">;</span></li></ol></pre></div></div><p><br></p></li><li><p>The previous command loads 6298 rows. Select the loaded rows to validate that data loaded successfully</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">SELECT </span><span class="pun">*</span><span class="pln"> FROM </span><span class="typ">Flight_Details</span><span class="pun">;</span></li></ol></pre></div></div><p><br></p><p><em>Note that data in an external stage is not counted towards your Snowflake storage; however, the cloud provider holding your data (e.g., AWS in this example) will charge you for storage costs.</em></p></li></ol></div><div class="practice--question-list--1HR9g practice--mt-md--3j-aS" data-purpose="question-list"><h4 class="ud-heading-md practice--mb-xs--Lpg-b">Questions for this assignment</h4><div><div class="question--question--152Yi"><div class="ud-text-bold question--title--2FD-U"><div data-purpose="safely-set-inner-html:rich-text-viewer:html" class="question--title-text--2kBEO rt-scaffolding"><p>Does data in external stage count towards your Snowflake storage?</p></div></div><div class="question--answer--2ASXa"></div></div></div></div></div>

# %% [markdown]
# <b>Does data in external stage count towards your Snowflake storage?</b><br>
# <p>No. It will get included by the Cloud provider like AWS, Azure, GCP</p>

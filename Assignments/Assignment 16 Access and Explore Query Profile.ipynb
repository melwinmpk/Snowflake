# %% [markdown]
# <div class="practice--panel--ejs8J"><div data-purpose="practice-component-text" class="rt-scaffolding"><h4>Access and Explore Query Profile</h4><p>This lab guides you through the process of running different queries and viewing the query profile for each query.</p><p><br></p><p>1. Login into the Snowflake web UI and navigate to the worksheet view. We will run 3 different SQLs using the worksheets and review each SQL's query profile.</p><p>2. You can use different methods to get to the query profile for a query. For example, if the query is still executing, it shows a unique ID, as shown below. Click the unique ID to get to the query profile for that query.</p><figure><img src="https://github.com/melwinmpk/Snowflake/assets/25386607/197a54e8-4a97-4450-a91f-7f9e0de00a4e"></figure><p><br></p><p>3. If the query has completed execution, then you can click the ellipsis button on the bottom right corner as shown and click "View Query Profile".</p><figure><img src="https://github.com/melwinmpk/Snowflake/assets/25386607/c33ecf1e-704e-4926-b532-f3ce6630eefb"></figure><p><br></p><p>4. The 3rd method to access the query profile is by clicking Activity and selecting Query History, as shown below. This method allows you to access the query profile for running, succeeded, or failed queries. To do so, click on the query to get the profile page.</p><figure><img src="https://github.com/melwinmpk/Snowflake/assets/25386607/6f45d796-f040-4d5f-9fc4-87090f15e378"></figure><p><br></p><p>5. Now that we know how to get to the query profile for a query let's run our queries and review the query profile.</p><p><br></p><p><strong>Query 1</strong></p><p>6. Run the following SQL to change your current database &amp;&nbsp;schema.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE SCHEMA SNOWFLAKE_SAMPLE_DATA</span><span class="pun">.</span><span class="pln">TPCDS_SF10TCL</span><span class="pun">;</span></li></ol></pre></div></div><p><br></p><p>7. Run the following SQL and then view the query profile for the query.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE SCHEMA SNOWFLAKE_SAMPLE_DATA</span><span class="pun">.</span><span class="pln">TPCDS_SF10TCL</span><span class="pun">;</span></li><li class="L1"><span class="kwd">with</span><span class="pln"> customer_total_return </span><span class="kwd">as</span></li><li class="L2"><span class="pun">(</span><span class="kwd">select</span><span class="pln"> sr_customer_sk </span><span class="kwd">as</span><span class="pln"> ctr_customer_sk</span></li><li class="L3"><span class="pun">,</span><span class="pln">sr_store_sk </span><span class="kwd">as</span><span class="pln"> ctr_store_sk</span></li><li class="L4"><span class="pun">,</span><span class="pln">sum</span><span class="pun">(</span><span class="pln">SR_RETURN_AMT_INC_TAX</span><span class="pun">)</span><span class="pln"> </span><span class="kwd">as</span><span class="pln"> ctr_total_return</span></li><li class="L5"><span class="kwd">from</span><span class="pln"> store_returns</span></li><li class="L6"><span class="pun">,</span><span class="pln">date_dim</span></li><li class="L7"><span class="kwd">where</span><span class="pln"> sr_returned_date_sk </span><span class="pun">=</span><span class="pln"> d_date_sk</span></li><li class="L8"><span class="kwd">and</span><span class="pln"> d_year </span><span class="pun">=</span><span class="lit">1999</span></li><li class="L9"><span class="kwd">group</span><span class="pln"> </span><span class="kwd">by</span><span class="pln"> sr_customer_sk</span></li><li class="L0"><span class="pun">,</span><span class="pln">sr_store_sk</span><span class="pun">)</span></li><li class="L1"><span class="kwd">select</span><span class="pln"> c_customer_id</span></li><li class="L2"><span class="kwd">from</span><span class="pln"> customer_total_return ctr1</span></li><li class="L3"><span class="pun">,</span><span class="pln">store</span></li><li class="L4"><span class="pun">,</span><span class="pln">customer</span></li><li class="L5"><span class="kwd">where</span><span class="pln"> ctr1</span><span class="pun">.</span><span class="pln">ctr_total_return </span><span class="pun">&gt;</span><span class="pln"> </span><span class="pun">(</span><span class="kwd">select</span><span class="pln"> avg</span><span class="pun">(</span><span class="pln">ctr_total_return</span><span class="pun">)*</span><span class="lit">1.2</span></li><li class="L6"><span class="kwd">from</span><span class="pln"> customer_total_return ctr2</span></li><li class="L7"><span class="kwd">where</span><span class="pln"> ctr1</span><span class="pun">.</span><span class="pln">ctr_store_sk </span><span class="pun">=</span><span class="pln"> ctr2</span><span class="pun">.</span><span class="pln">ctr_store_sk</span><span class="pun">)</span></li><li class="L8"><span class="kwd">and</span><span class="pln"> s_store_sk </span><span class="pun">=</span><span class="pln"> ctr1</span><span class="pun">.</span><span class="pln">ctr_store_sk</span></li><li class="L9"><span class="kwd">and</span><span class="pln"> s_state </span><span class="pun">=</span><span class="pln"> </span><span class="str">'NM'</span></li><li class="L0"><span class="kwd">and</span><span class="pln"> ctr1</span><span class="pun">.</span><span class="pln">ctr_customer_sk </span><span class="pun">=</span><span class="pln"> c_customer_sk</span></li><li class="L1"><span class="pln">order </span><span class="kwd">by</span><span class="pln"> c_customer_id</span></li><li class="L2"><span class="pln">limit </span><span class="lit">100</span><span class="pun">;</span></li></ol></pre></div></div><p><br></p><p>8. View the Query Profile for the above query. In the first (bottommost) node, Snowflake scans the STORE_RETURNS table. Note how many partitions the table contains and how many did Snowflake scan.</p><p><br></p><p><strong>Query 2</strong></p><p>9. Now run the following SQL and then view the query profile.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE SCHEMA SNOWFLAKE_SAMPLE_DATA</span><span class="pun">.</span><span class="pln">TPCDS_SF10TCL</span><span class="pun">;</span></li><li class="L1"><span class="kwd">select</span><span class="pln"> c_customer_id customer_id</span></li><li class="L2"><span class="pun">,</span><span class="pln">c_first_name customer_first_name</span></li><li class="L3"><span class="pun">,</span><span class="pln">c_last_name customer_last_name</span></li><li class="L4"><span class="pun">,</span><span class="pln">c_preferred_cust_flag customer_preferred_cust_flag</span></li><li class="L5"><span class="pun">,</span><span class="pln">c_birth_country customer_birth_country</span></li><li class="L6"><span class="pun">,</span><span class="pln">c_login customer_login</span></li><li class="L7"><span class="pun">,</span><span class="pln">c_email_address customer_email_address</span></li><li class="L8"><span class="kwd">from</span><span class="pln"> customer</span><span class="pun">;</span></li></ol></pre></div></div><p>10. Review the query profile.</p><p><br></p><p><strong>Query 3</strong></p><p>11. Now run the following SQL and then view the query profile.</p><div class="ud-component--base-components--code-block"><div><pre class="prettyprint linenums prettyprinted" role="presentation" style=""><ol class="linenums"><li class="L0"><span class="pln">USE SCHEMA SNOWFLAKE_SAMPLE_DATA</span><span class="pun">.</span><span class="pln">TPCDS_SF10TCL</span><span class="pun">;</span></li><li class="L1"><span class="kwd">select</span><span class="pln"> </span><span class="pun">*</span><span class="pln"> </span><span class="kwd">from</span></li><li class="L2"><span class="pun">(</span></li><li class="L3"><span class="kwd">select</span><span class="pln"> d_date_sk</span></li><li class="L4"><span class="pun">,</span><span class="pln">sum</span><span class="pun">(</span><span class="pln">SR_RETURN_AMT_INC_TAX</span><span class="pun">)</span><span class="pln"> </span><span class="kwd">as</span><span class="pln"> ctr_total_return</span></li><li class="L5"><span class="kwd">from</span><span class="pln"> store_returns</span></li><li class="L6"><span class="pun">,</span><span class="pln">date_dim</span></li><li class="L7"><span class="kwd">where</span><span class="pln"> sr_returned_date_sk </span><span class="pun">=</span><span class="pln"> d_date_sk</span></li><li class="L8"><span class="kwd">and</span><span class="pln"> d_year </span><span class="pun">=</span><span class="lit">1999</span></li><li class="L9"><span class="kwd">group</span><span class="pln"> </span><span class="kwd">by</span><span class="pln"> d_date_sk</span></li><li class="L0"><span class="pun">)</span><span class="pln"> A</span></li><li class="L1"><span class="kwd">where</span><span class="pln"> ctr_total_return </span><span class="pun">&gt;</span><span class="pln"> </span><span class="pun">(</span><span class="pln"> </span><span class="kwd">select</span><span class="pln"> avg</span><span class="pun">(</span><span class="pln">SR_RETURN_AMT_INC_TAX</span><span class="pun">)</span></li><li class="L2"><span class="kwd">from</span><span class="pln"> store_returns</span></li><li class="L3"><span class="pun">);</span></li></ol></pre></div></div><p><br></p><p>12. Review the query profile. In the first (bottommost) node, Snowflake scans the STORE_RETURNS table. Note how many partitions the table contains and how many did Snowflake scan.</p><p><br></p><p><br></p><p><br></p></div><div class="practice--question-list--1HR9g practice--mt-md--3j-aS" data-purpose="question-list"><h4 class="ud-heading-md practice--mb-xs--Lpg-b">Questions for this assignment</h4><div><div class="question--question--152Yi"><div class="ud-text-bold question--title--2FD-U"><div data-purpose="safely-set-inner-html:rich-text-viewer:html" class="question--title-text--2kBEO rt-scaffolding"><p>Consider the query profile for the <strong>1st</strong> query.</p><p>1- How many partitions were scanned by Snowflake when accessing the STORE_RETURNS table?</p><p>2- Did any partition pruning occur?</p></div></div><div class="question--answer--2ASXa"></div></div><div class="question--question--152Yi"><div class="ud-text-bold question--title--2FD-U"><div data-purpose="safely-set-inner-html:rich-text-viewer:html" class="question--title-text--2kBEO rt-scaffolding"><p>Consider the query profile for the <strong>3rd</strong> query.</p><p>1- How many partitions were scanned by Snowflake when accessing the STORE_RETURNS table?</p><p>2- Did any partition pruning occur?</p><p>3- Was Snowflake able to read any data from the cache?</p></div></div><div class="question--answer--2ASXa"></div></div></div></div></div>

# %% [markdown]
# <div class="question--question--152Yi"><div class="ud-text-bold question--title--2FD-U"><div data-purpose="safely-set-inner-html:rich-text-viewer:html" class="question--title-text--2kBEO rt-scaffolding"><p>Consider the query profile for the <strong>1st</strong> query.</p><p>1- How many partitions were scanned by Snowflake when accessing the STORE_RETURNS table?</p><p>2- Did any partition pruning occur?</p></div></div><div class="question--answer--2ASXa"><div data-purpose="safely-set-inner-html:submission:user-answer-body"><p>Partitions scanned = <strong>1521</strong></p><p>Partitions total = <strong>7757</strong></p><p>Snowflake did not scan unneeded partitions; hence partition pruning occurred.</p><p><br></p><p>Note: your results may vary a bit.</p></div></div></div>
#
# <div class="question--question--152Yi"><div class="ud-text-bold question--title--2FD-U"><div data-purpose="safely-set-inner-html:rich-text-viewer:html" class="question--title-text--2kBEO rt-scaffolding"><p>Consider the query profile for the <strong>3rd</strong> query.</p><p>1- How many partitions were scanned by Snowflake when accessing the STORE_RETURNS table?</p><p>2- Did any partition pruning occur?</p><p>3- Was Snowflake able to read any data from the cache?</p></div></div><div class="question--answer--2ASXa"><div data-purpose="safely-set-inner-html:submission:user-answer-body"><p>Percentage scanned from cache = <strong>7.04%</strong></p><p>Partitions scanned = <strong>7757</strong></p><p>Partitions total = <strong>7757</strong></p><p><br></p><p>Snowflake scanned all partitions; hence NO partition pruning occurred, and Snowflake was also able to pull some of the data from the virtual warehouse cache since the previous query brought some data into the cache.</p><p><br></p><p>Note: your results may vary a bit.</p></div></div></div>
